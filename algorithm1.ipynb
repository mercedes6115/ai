# %% [markdown]
# <a href="https://colab.research.google.com/github/mercedes6115/ai/blob/main/algorithm1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 알고리즘
# 문제나 과제를 해결하기 위한 처리 절차를 구체적인 순서로 표현한 아이디어 또는 생각 
# 알고리즘 자체는 일상생활에서도 많이 사용하고 있다
# 요리의 레시피, 음악의 악보 ,가전제품 사용설명서 등등
# 문자, 기호 ,일러스트 등으로 나타낸다

# %%
# 알고리즘과 프로그램
# 알고리즘을 프로그래밍 언어로 기술하면 프로그램이 된다
# 프로그래밍 언어는 컴퓨터에 지시하기 위한 인공 언어이다

# %%
# 프로그램 작성에서의 알고리즘
# 프로그램 작성은 기획, 설계, 프로그래밍, 디버그로 진행된다
# 알고리즘은 설계 단계에서 필요하다

# %%
# 좋은 알고리즘이란 
# 알기 쉽다 (쉬운 이해)
# 속도가 빠르다
# 효율적이다
# 재이용이 쉽다

# %%
# 왜 알고리즘을 공부해야 하나
# 좋은 프로그램을 만들기 위해(빠르고, 효율적, 범용성)
# 프로그래미의 좋고 나쁨을 판단하기 위해
# 프로그램 작성 과정 전체를 효율화하기 위해
# 프로그램 기술을 향상시키기 위해

# %%
# 알고리즘의 조건
# 정확한 결과를 얻을 수 있어야 한다(알고리즘은 문제나 과제를 해결하기 위한 절차)
# 반드시 종료되어야 한다(중간 처리나 절차가 잘못 만들어지면 무한 반복)

# %%
# 알고리즘의 기본형 3가지
# 순차 구조: 처음부터 순서대로 처리하는 절차
# 알고리즘 중에서도 가장 많이 사용된다

# %%
# 선택 구조: 조건식으로 판단해 실행할 절차를 전환하는 주고
# 반복 구조: 조건을 만족하는 동안 같은 처리를 반복하는 절차

# %%
# 의사코드 pseudo code

# 1.순차구조
# - 수퍼에 간다
# - 라면을 산다
# - 집으로 돌아온다

# 2. 선택구조 
# - 수퍼에 간다
# - 라면이 있나?
# -  라면을 산다
# -  -----------
# -  떡을 산다
# - 집으로 돌아온다

# -3. 반복구조
# - 수퍼에 간다
# - 라면이 있나?
# -  라면을 산다
# -  -----------
# -  떡을 산다
# - 거스름돈이 500원 보다 많다
# -  - 붕어빵을 산다
# - 집으로 돌아온다

# %%
# 삼각형의 면적을 계산하는 알고리즘 
# 삼각형의 면적 = (밑변*높이)/2

#- 밑변과 높이를 입력
#- area <- base * height / 2
#- area 출력

# 순서도 작성

# %%
def get_area(base, height):
  area = base * height/2
  print(height)

get_area(10,12)
# Out:
# 12

# %%
# 2개의 데이터의 대소를 판단하는 알고리즘 

#의사코드

# a,b입력
# a>b
# max=a 
# a=b
# a와b는 같다
# a<b
# max=b
#print(max)

# %% [markdown]
# ![삼각형면적 순서도.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![알고리즘 순서도.jpg](data:image/jpeg;base64,...)

# %%
#########################################################################
# Function
#########################################################################

# %%
# 가변 매개변수
"""
def print_n_times(n, *val):
  for i in range(n):
    for v in val:
      print(v)
"""
"""
def sum_all(*val):
  print(sum(val))

sum_all(1,2,3,4,5,6,7,8)
"""
# Out:
# 36

# %%
# 기본 매개변수

def print_3(val,n=4): # 기본 매개변수를 설정해두면 넣어도 돌아가고 안넣어도 돌아간다 
  for i in range(n):  # 단 순서는 바꾸면 에러가 난다 
    print(val)        # 관용적으로 가변 매개변수의 이름은 args로 표현한다
print_3('hi')
print_3('hi',7)
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi

# %%
def test(a,b=10,c=100):
  print(a+b+c)
test(10,20,30)
# Out:
# 60

# %%
def return_test():
  print('A위치입니다')
  return  # return을 만나는 위치에서 끝난다
  print('B위치입니다')

return_test()

def return_test1():

  return 100

return_test1()
# Out:
# A위치입니다

# %%
def sum_all(start,end):
  output=0
  for i in range(start,end+1):
    output +=i

  return output

# %%
def hello():
  print('hi')
  return hello()

hello()

# %%
result = 1 
for item in range(1, a+1, 1): 
  result *= item 
  print(result)

# %%
# 재귀함수를 이용한 팩토리얼 함수 구현
def factorial(n): 
  if(n > 1): 
    return (n * factorial(n - 1))
  else:
    return 1


print(factorial(10))
# Out:
# 3628800

# %%
def fibbo(n):
    if n==1 or n==2:
        return 1
    else:
        return fibbo(n-1) + fibbo(n-2)

print(fibbo(1))
print(fibbo(2))
print(fibbo(3))
print(fibbo(4))
print(fibbo(5))
# Out:
# 1
# 1
# 2
# 3
# 5

# %%
# 튜플과 함수
# 튜플은 함수의 리턴에 많이 사용된다\
def test():
  return 10,20
# 함수와 매서드 클래스 안에서 함수를 선언하면 매서드 라고한다

# %%
def add_mul(choice,*args):
  if choice == 'add':
    result=0
    for i in args:
      result =result+i
  elif choice == 'mul':
    result=1
    for i in args:
      result = result*i
  return result

print(add_mul('add', 1,2,3,4,5))
print(add_mul('mul', 1,2,3,4,5))
# Out:
# 15
# 120

# %%
add= lambda a,b:a+b

print(add(3,4))

# 객체와 인스턴스
# a=cookie()  a는 객체   a는 쿠키의 인스턴스   // a는 쿠키의 객체라고 하지 않는다 클래스와의 관계를 설명할때 클래스의 인스턴스이다 라고한다
# Out:
# 7
